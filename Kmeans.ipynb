# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import os
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(os.path.join("..", "..", "..", "cleanedfinalbeerdata.csv"))
df.head(25)
# Out:
#     Memes      id                        name  \
# 0       0  Ku1a3J          Adnams Ginger Beer
# 1       1  0S5yCW                      Alster
# 2       2  KMcfsN          Altenburger Radler
# 3       3  t7flbd            Amstel Oud Bruin
# 4       4  3Or1VY             Apoldaer Radler
# 5       5  iEZqaZ              Bays Light Ale
# 6       6  KEhqHy       Beck’s Chilled Orange
# 7       7  BBsGkH          Beck’s Green Lemon
# 8       8  nVb4ti                  Beck’s Ice
# 9       9  ibUawL       Berliner Kindl Radler
# 10     10  RVKKEP             Berliner Weisse
# 11     11  U3lqIl             Bischoff Radler
# 12     12  wKA3eP            Bitburger Radler
# 13     13  irTMtk             Braugold Radler
# 14     14  GfcCAv            Braustolz Diesel
# 15     15  eLtO1U            Braustolz Radler
# 16     16  2aHWKk    Dingslebener White Grape
# 17     17  Jr53eR  Dry Hopped Berliner Weisse
# 18     18  fVSUXE            Einbecker Alster
# ...

# %% [markdown]
# avgsrm = df['srmId'].mean()
# avgibu = df['ibu'].mean()
# avgibu
#
# finaldf = df[(df['ibu'] < 200) & (df.description.notnull())]
# finaldf['ibunew'] = np.where(finaldf['ibu'].isna==True, avgibu, finaldf['ibu'])
# finaldf['srmnew'] = np.where(finaldf['srmId'].isna==True, avgsrm, finaldf['srmId'])
#
# # # finaldf = finaldf1[finaldf1['ibu'] < 200]
# finaldf.head(25)

# %%
# avgsrm = round(df['srmId'].mean())
# avgibu = round(df['ibu'].mean())
# sdibu = round(np.std(df['ibu']))
# sdsrm = round(np.std(df['srmId']))
import random
import decimal



# pd.options.mode.chained_assignment = None
# decimal.Decimal(random.randrange(-10, 10))/100

finaldf1 = df[(df.description.notnull())]

# for row in finaldf1.iterrows():
#     finaldf1['newabv'] == finaldf['abv']+decimal.Decimal(random.randrange(-10, 10))/100

# finaldf1['light kw'] = np.where(finaldf1['description'].str.contains("light", case=False, na=False), 1, 0) 
# finaldf1['dark kw'] = np.where(finaldf1['description'].str.contains("dark", case=False, na=False), 1, 0) 
# finaldf1['hoppy kw'] = np.where(finaldf1['description'].str.contains("hoppy|hopp|bitter", case=False, na=False), 1, 0) 
# finaldf1['not hoppy kw'] = np.where(finaldf1['description'].str.contains("sweet|smooth", case=False, na=False), 1, 0) 

finaldf1.head(50)
# Out:
#     Unnamed: 0      id                         name  \
# 0            0  Ku1a3J           Adnams Ginger Beer
# 1            1  0S5yCW                       Alster
# 4            4  3Or1VY              Apoldaer Radler
# 5            5  iEZqaZ               Bays Light Ale
# 6            6  KEhqHy        Beck’s Chilled Orange
# 8            8  nVb4ti                   Beck’s Ice
# 9            9  ibUawL        Berliner Kindl Radler
# 10          10  RVKKEP              Berliner Weisse
# 11          11  U3lqIl              Bischoff Radler
# 12          12  wKA3eP             Bitburger Radler
# 13          13  irTMtk              Braugold Radler
# 14          14  GfcCAv             Braustolz Diesel
# 15          15  eLtO1U             Braustolz Radler
# 19          19  3BjgNn        Einbecker Green-Lemon
# 20          20  OsDwRF                    Framboise
# 22          22  WZjHr7                  Früh Radler
# 25          25  KAh9n5               Greizer Radler
# ...

# %%
import random
random.randint(-6, 6)

avgsrm
avgibu
sdibu
sdsrm

ibuvar = round(sdibu/5)
srmvar = round(sdsrm/5)


finaldf1['ibunew1'] = np.where((pd.isna(finaldf1['ibu'])==True) & (finaldf1['hoppy kw']==1),
                              avgibu+sdibu, finaldf1['ibu'])
finaldf1['ibunew2'] = np.where((pd.isna(finaldf1['ibu'])==True) & (finaldf1['not hoppy kw']==1),
                              avgibu-sdibu, finaldf1['ibu']) 
finaldf1['srmnew1'] = np.where((pd.isna(finaldf1['srmId'])==True) & (finaldf1['light kw']==1),
                              avgsrm-sdsrm, finaldf1['srmId'])
finaldf1['srmnew2'] = np.where((pd.isna(finaldf1['srmId'])==True) & (finaldf1['dark kw']==1),
                              avgsrm+sdsrm, finaldf1['srmId'])

# finaldf1['finalsrm'] = np.where((pd.isna(finaldf1['srmnew1'])==True) & (pd.isna(finaldf1['srmnew2'])==True),
#                               avgsrm, finaldf1['srmnew1'])
# finaldf1['finalibu'] = np.where((pd.isna(finaldf1['ibunew1'])==True) & (pd.isna(finaldf1['ibunew2'])==True),
#                               avgibu, finaldf1['ibunew1'])



finaldf1.head(25)
# Out:
# C:\Users\Peter\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Peter\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Peter\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Generate 4 clusters of random data.
# from sklearn.datasets.samples_generator import make_blobs

# data, _ = make_blobs(n_samples=300, centers=4,
#                      cluster_std=0.60, random_state=0)
# data
# Out:
# array([[ 8.36856841e-01,  2.13635938e+00],
#        [-1.41365810e+00,  7.40962324e+00],
#        [ 1.15521298e+00,  5.09961887e+00],
#        [-1.01861632e+00,  7.81491465e+00],
#        [ 1.27135141e+00,  1.89254207e+00],
#        [ 3.43761754e+00,  2.61654166e-01],
#        [-1.80822253e+00,  1.59701749e+00],
#        [ 1.41372442e+00,  4.38117707e+00],
#        [-2.04932168e-01,  8.43209665e+00],
#        [-7.11099611e-01,  8.66043846e+00],
#        [-1.71237268e+00,  2.77780226e+00],
#        [-2.67000792e+00,  8.35389140e+00],
#        [ 1.24258802e+00,  4.50399192e+00],
#        [-2.22783649e+00,  6.89479938e+00],
#        [ 1.45513831e+00, -2.91989981e-02],
#        [ 4.53791789e-01,  3.95647753e+00],
#        [ 1.06923853e+00,  4.53068484e+00],
#        [ 2.56936589e+00,  5.07048304e-01],
#        [-1.06690610e+00,  3.13165795e+00],
#        [-1.07859101e+00,  2.20451529e+00],
#        [ 2.71506328e+00,  1.29082190e+00],
#        [ 1.77710994e+00,  1.18655254e+00],
# ...

# %%
# Plot the data
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

x = np.array(finaldf1['abv'])
y = np.array(finaldf1['srmId'])
z = np.array(finaldf1['ibu'])
print(x)
print(y)
print(z)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)
ax.set_xlabel('ABV %')
ax.set_ylabel('SRM - light to dark, scale 1 to 40')
ax.set_zlabel('IBU - bitterness')

plt.show()
# Out:
# [2.5 2.5 2.5 ... 4.5 4.5 4.5]
# [nan nan nan ... nan  6. nan]
# [nan nan nan ... nan 15. 58.]

# %%
# Use n_clusters=4 as the k value
# We can see from the plot above that there are 4 clusters
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=15)

# %%
import numpy as np
srmdata = np.array(finaldf1['abv'].values, finaldf1['srmId'].values, finaldf1['srmId'].values)))
srmdata
kmeans.fit(srmdata)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-d29ba0a761fa> in <module>()
#       2 srmdata = np.array(list(zip(finaldf1['abv'].values, finaldf1['srmId'].values, finaldf1['srmId'].values)))
#       3 srmdata
# ----> 4 kmeans.fit(srmdata)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y)
#     885         """
#     886         random_state = check_random_state(self.random_state)
# --> 887         X = self._check_fit_data(X)
#     888
#     889         self.cluster_centers_, self.labels_, self.inertia_, self.n_iter_ = \
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\k_means_.py in _check_fit_data(self, X)
#     856     def _check_fit_data(self, X):
#     857         """Verify that the number of samples given is larger than k"""
# ...

# %%
# Predict the clusters
predicted_clusters = kmeans.predict(srmdata)
# Out:
# C:\Users\Peter\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#      Unnamed: 0      id                       name  \
# 60           60  b5a5de                4 Foot Drop
# 66           66  1AiMAz    801 Small Batch Pilsner
# 67           67  wA9gZx                Abita Light
# 112         112  QObMrh  Artsy Tartsy with Peaches
# 129         129  iO2ZqT                   Balmoral
#
#                                            description  abv  styleId  id.1  \
# 60   An American Style Pale Ale that is bold and tr...  4.0     25.0  25.0
# 66   Light-bodied and refreshing, this quaffable Pi...  4.0     75.0  75.0
# ...

# %%
# Plot the predicted clusters to see if the model predicted the correct clusters
# This is visual validation that the model was trained correctly.
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c=predicted_clusters)
ax.set_xlabel('ABV %')
ax.set_ylabel('SRM - light to dark, scale 1 to 40')
ax.set_zlabel('IBU - bitterness')

plt.show()

# %%
plt.scatter(finaldf1['abv'], finaldf1['ibu'])

# %%
ibudata = np.array(list(zip(finaldf1['abv'].values, finaldf1['ibu'].values)))
ibudata
kmeans.fit(ibudata)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=13, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
predicted_clusters2 = kmeans.predict(ibudata)
finaldf1['IBU predicted group'] = predicted_clusters2
finaldf1.head()
# Out:
# C:\Users\Peter\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#      Unnamed: 0      id                       name  \
# 60           60  b5a5de                4 Foot Drop
# 66           66  1AiMAz    801 Small Batch Pilsner
# 67           67  wA9gZx                Abita Light
# 112         112  QObMrh  Artsy Tartsy with Peaches
# 129         129  iO2ZqT                   Balmoral
#
#                                            description  abv  styleId  id.1  \
# 60   An American Style Pale Ale that is bold and tr...  4.0     25.0  25.0
# 66   Light-bodied and refreshing, this quaffable Pi...  4.0     75.0  75.0
# ...

# %%
df2 = pd.DataFrame(np.array([['UserBeer', 'memes', 5]]), columns=['id', 'description', 'abv'])
df2
# Out:
#          id description abv
# 0  UserBeer       memes   5

# %%
chosenbeergroup = finaldf1[finaldf1['id'].str.contains("SgNMNV")]['predicted group'].values[0]
chosenbeergroup

# filterdf = finaldf1[finaldf1['predicted group']==chosenbeergroup]
# numberingroup = filterdf['id'].count()



# import random

# selectarr = []

# for x in range(0, 6):
#     selectarr.append (random.randint(0, int(numberingroup)))
    
# selectarr

# finaluserdf = filterdf.iloc[selectarr]
# Out:
# 11

# %%
plt.scatter(ibudata[:, 0], ibudata[:, 1], c=predicted_clusters2, s=50, cmap='viridis')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score


# documents = v.fit_transform(finaldf1['description'].values.astype('U'))
documents = ["Human machine interface for lab abc computer applications",
             "A survey of user opinion of computer system response time",
             "The EPS user interface management system",
             "System and human system engineering testing of EPS",
             "Relation of user perceived response time to error measurement",
             "The generation of random binary unordered trees",
             "The intersection graph of paths in trees",
             "Graph minors IV Widths of trees and well quasi ordering",
             "Graph minors A survey"]

documents = np.ndarray.tolist(finaldf1['description'].values)


my_stop_words = text.ENGLISH_STOP_WORDS.union(["beer"])
vectorizer = TfidfVectorizer(stop_words=my_stop_words, decode_error='replace', encoding='utf-8')

X = vectorizer.fit_transform(documents)
# true_k = 2
# model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
# model.fit(X)

documents
# Out:
# ['Our new lower alcohol Ginger Beer marks an exciting time at Adnams.\r\r\n\r\r\nWe wanted to create something fun and exciting, but with a real Adnams flavour.\r\r\n\r\r\nBrewed in our usual way, we’ve used the wort from bottled Broadside to create the base for this beer. We then added ginger and orange peel into the kettle, fermented it and then added more ginger, lemon and lime zest as well as some sugar to sweeten the flavour slightly.\r\r\n\r\r\nThe end result is a beer with authenticity and flavour, rich in ginger and citrus notes, spice with a malty sweetness.  This is definitely more of a beer, than a ginger!\r\r\n\r\r\nAt only 2.5% abv, Adnams Ginger Beer is the perfect accompaniment to all summer drinking occasions.',
#  'Refreshingly Lemony, beautifully mild and even not too sweet. The demimonde Hemelinger with only 2.5% vol. Cold made it tastes the best.',
#  'Beer mixed drink made \u200b\u200bof 50% and 50% Apoldaer bells beer with lemon soda sweeteners.',
# ...

# %%
kmeans = KMeans(n_clusters=15)
srmdata = np.array(list(zip(finaldf1['newabv'].values)), X)

kmeans.fit(srmdata)
predicted_clusters = kmeans.predict(srmdata)

finaldf1['predicted group'] = predicted_clusters
finaldf1.head(19000)
# Out:
# C:\Users\Peter\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        Unnamed: 0      id                                               name  \
# 0               0  Ku1a3J                                 Adnams Ginger Beer
# 1               1  0S5yCW                                             Alster
# 4               4  3Or1VY                                    Apoldaer Radler
# 5               5  iEZqaZ                                     Bays Light Ale
# 6               6  KEhqHy                              Beck’s Chilled Orange
# 8               8  nVb4ti                                         Beck’s Ice
# 9               9  ibUawL                              Berliner Kindl Radler
# ...
